# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../input/fer2013/train" # Directory containing the training data
test_dir = "../input/fer2013/test"  # Directory containing the validation data

# %%
# First, set up the data generators
train_datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    rescale=1./255,
    validation_split=0.2
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
# Set up the generators with shuffle=True
train_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="training",
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="validation",
    shuffle=True
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 
from tensorflow.keras.layers import (
    Dense, 
    Dropout, 
    Flatten,
    Conv2D, 
    MaxPooling2D,
    BatchNormalization
)


# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(
    loss="categorical_crossentropy", 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Changed from lr to learning_rate
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 46, 46, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 44, 44, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 44, 44, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 20, 20, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 20, 20, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 18, 18, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 18, 18, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 9, 9, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 9, 9, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 7, 7, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 7, 7, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 5, 5, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 5, 5, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │           1,799 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,178,071 (15.94 MB)
#  Trainable params: 1,391,943 (5.31 MB)
#  Non-trainable params: 2,240 (8.75 KB)
#  Optimizer params: 2,783,888 (10.62 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# Define callbacks
checkpoint_callback = ModelCheckpoint(
    filepath='model.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Train the model with callbacks
# Note: Remove steps_per_epoch and validation_steps
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpoint_callback, reduce_lr, early_stopping],
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.1751 - loss: 2.9379
# Epoch 1: val_accuracy improved from -inf to 0.23883, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 239ms/step - accuracy: 0.1751 - loss: 2.9375 - val_accuracy: 0.2388 - val_loss: 1.8698 - learning_rate: 1.0000e-04
# Epoch 2/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2206 - loss: 2.4789
# Epoch 2: val_accuracy improved from 0.23883 to 0.32612, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.2207 - loss: 2.4787 - val_accuracy: 0.3261 - val_loss: 1.7729 - learning_rate: 1.0000e-04
# Epoch 3/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2612 - loss: 2.2282
# Epoch 3: val_accuracy improved from 0.32612 to 0.34497, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.2612 - loss: 2.2281 - val_accuracy: 0.3450 - val_loss: 1.7294 - learning_rate: 1.0000e-04
# Epoch 4/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2882 - loss: 2.1122
# Epoch 4: val_accuracy improved from 0.34497 to 0.37221, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.2882 - loss: 2.1120 - val_accuracy: 0.3722 - val_loss: 1.6129 - learning_rate: 1.0000e-04
# Epoch 5/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3136 - loss: 1.9943
# Epoch 5: val_accuracy did not improve from 0.37221
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.3136 - loss: 1.9942 - val_accuracy: 0.3652 - val_loss: 1.7080 - learning_rate: 1.0000e-04
# Epoch 6/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3449 - loss: 1.8814
# Epoch 6: val_accuracy improved from 0.37221 to 0.40642, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.3449 - loss: 1.8813 - val_accuracy: 0.4064 - val_loss: 1.5184 - learning_rate: 1.0000e-04
# Epoch 7/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3463 - loss: 1.8190
# Epoch 7: val_accuracy improved from 0.40642 to 0.46369, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.3464 - loss: 1.8189 - val_accuracy: 0.4637 - val_loss: 1.4389 - learning_rate: 1.0000e-04
# Epoch 8/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3756 - loss: 1.7462
# Epoch 8: val_accuracy did not improve from 0.46369
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.3756 - loss: 1.7462 - val_accuracy: 0.4546 - val_loss: 1.4250 - learning_rate: 1.0000e-04
# Epoch 9/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3916 - loss: 1.6655
# Epoch 9: val_accuracy improved from 0.46369 to 0.49232, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 32s 86ms/step - accuracy: 0.3916 - loss: 1.6655 - val_accuracy: 0.4923 - val_loss: 1.3515 - learning_rate: 1.0000e-04
# Epoch 10/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4082 - loss: 1.6145
# Epoch 10: val_accuracy improved from 0.49232 to 0.49930, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.4082 - loss: 1.6145 - val_accuracy: 0.4993 - val_loss: 1.3318 - learning_rate: 1.0000e-04
# Epoch 11/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4289 - loss: 1.5445
# Epoch 11: val_accuracy did not improve from 0.49930
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 31s 84ms/step - accuracy: 0.4289 - loss: 1.5445 - val_accuracy: 0.4749 - val_loss: 1.4383 - learning_rate: 1.0000e-04
# Epoch 12/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4354 - loss: 1.5227
# Epoch 12: val_accuracy improved from 0.49930 to 0.54330, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 83ms/step - accuracy: 0.4355 - loss: 1.5225 - val_accuracy: 0.5433 - val_loss: 1.2405 - learning_rate: 1.0000e-04
# Epoch 13/50
# 357/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4499 - loss: 1.4801
# Epoch 13: val_accuracy did not improve from 0.54330
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.4499 - loss: 1.4800 - val_accuracy: 0.5293 - val_loss: 1.2484 - learning_rate: 1.0000e-04
# Epoch 14/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4619 - loss: 1.4385
# Epoch 14: val_accuracy improved from 0.54330 to 0.54818, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.4619 - loss: 1.4385 - val_accuracy: 0.5482 - val_loss: 1.2123 - learning_rate: 1.0000e-04
# Epoch 15/50
# 357/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4781 - loss: 1.3995
# Epoch 15: val_accuracy improved from 0.54818 to 0.55656, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.4781 - loss: 1.3995 - val_accuracy: 0.5566 - val_loss: 1.1970 - learning_rate: 1.0000e-04
# Epoch 16/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4838 - loss: 1.3697
# Epoch 16: val_accuracy did not improve from 0.55656
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.4838 - loss: 1.3697 - val_accuracy: 0.5447 - val_loss: 1.2088 - learning_rate: 1.0000e-04
# Epoch 17/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4912 - loss: 1.3452
# Epoch 17: val_accuracy improved from 0.55656 to 0.56983, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 81ms/step - accuracy: 0.4912 - loss: 1.3452 - val_accuracy: 0.5698 - val_loss: 1.1425 - learning_rate: 1.0000e-04
# Epoch 18/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5035 - loss: 1.3108
# Epoch 18: val_accuracy improved from 0.56983 to 0.57193, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.5035 - loss: 1.3108 - val_accuracy: 0.5719 - val_loss: 1.1567 - learning_rate: 1.0000e-04
# Epoch 19/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5133 - loss: 1.2975
# Epoch 19: val_accuracy did not improve from 0.57193
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.5134 - loss: 1.2975 - val_accuracy: 0.5601 - val_loss: 1.1670 - learning_rate: 1.0000e-04
# Epoch 20/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5227 - loss: 1.2694
# Epoch 20: val_accuracy improved from 0.57193 to 0.58939, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.5227 - loss: 1.2694 - val_accuracy: 0.5894 - val_loss: 1.1069 - learning_rate: 1.0000e-04
# Epoch 21/50
# 357/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5296 - loss: 1.2445
# Epoch 21: val_accuracy did not improve from 0.58939
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.5296 - loss: 1.2446 - val_accuracy: 0.5642 - val_loss: 1.1284 - learning_rate: 1.0000e-04
# Epoch 22/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5403 - loss: 1.2310
# Epoch 22: val_accuracy did not improve from 0.58939
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 27s 74ms/step - accuracy: 0.5403 - loss: 1.2310 - val_accuracy: 0.5754 - val_loss: 1.1271 - learning_rate: 1.0000e-04
# Epoch 23/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5367 - loss: 1.2258
# Epoch 23: val_accuracy did not improve from 0.58939
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 31s 84ms/step - accuracy: 0.5367 - loss: 1.2258 - val_accuracy: 0.5726 - val_loss: 1.1582 - learning_rate: 1.0000e-04
# Epoch 24/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5478 - loss: 1.2077
# Epoch 24: val_accuracy did not improve from 0.58939
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5478 - loss: 1.2077 - val_accuracy: 0.5712 - val_loss: 1.1318 - learning_rate: 1.0000e-04
# Epoch 25/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5548 - loss: 1.1862
# Epoch 25: val_accuracy improved from 0.58939 to 0.59288, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.5548 - loss: 1.1862 - val_accuracy: 0.5929 - val_loss: 1.0701 - learning_rate: 1.0000e-04
# Epoch 26/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5609 - loss: 1.1595
# Epoch 26: val_accuracy did not improve from 0.59288
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 78ms/step - accuracy: 0.5609 - loss: 1.1595 - val_accuracy: 0.5887 - val_loss: 1.0648 - learning_rate: 1.0000e-04
# Epoch 27/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5689 - loss: 1.1580
# Epoch 27: val_accuracy improved from 0.59288 to 0.60265, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.5689 - loss: 1.1580 - val_accuracy: 0.6027 - val_loss: 1.0553 - learning_rate: 1.0000e-04
# Epoch 28/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5682 - loss: 1.1418
# Epoch 28: val_accuracy improved from 0.60265 to 0.60335, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.5682 - loss: 1.1418 - val_accuracy: 0.6034 - val_loss: 1.0692 - learning_rate: 1.0000e-04
# Epoch 29/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5728 - loss: 1.1296
# Epoch 29: val_accuracy did not improve from 0.60335
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 31s 85ms/step - accuracy: 0.5728 - loss: 1.1296 - val_accuracy: 0.5992 - val_loss: 1.0622 - learning_rate: 1.0000e-04
# Epoch 30/50
# 357/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5785 - loss: 1.1235
# Epoch 30: val_accuracy improved from 0.60335 to 0.61034, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.5784 - loss: 1.1236 - val_accuracy: 0.6103 - val_loss: 1.0257 - learning_rate: 1.0000e-04
# Epoch 31/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5804 - loss: 1.1162
# Epoch 31: val_accuracy did not improve from 0.61034
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.5804 - loss: 1.1162 - val_accuracy: 0.6082 - val_loss: 1.0601 - learning_rate: 1.0000e-04
# Epoch 32/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5835 - loss: 1.1128
# Epoch 32: val_accuracy improved from 0.61034 to 0.63617, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.5835 - loss: 1.1128 - val_accuracy: 0.6362 - val_loss: 0.9970 - learning_rate: 1.0000e-04
# Epoch 33/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5819 - loss: 1.1124
# Epoch 33: val_accuracy did not improve from 0.63617
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.5820 - loss: 1.1123 - val_accuracy: 0.6194 - val_loss: 1.0157 - learning_rate: 1.0000e-04
# Epoch 34/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5928 - loss: 1.0897
# Epoch 34: val_accuracy did not improve from 0.63617
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.5928 - loss: 1.0897 - val_accuracy: 0.6201 - val_loss: 1.0223 - learning_rate: 1.0000e-04
# Epoch 35/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5970 - loss: 1.0744
# Epoch 35: val_accuracy improved from 0.63617 to 0.63827, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.5969 - loss: 1.0745 - val_accuracy: 0.6383 - val_loss: 0.9923 - learning_rate: 1.0000e-04
# Epoch 36/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5958 - loss: 1.0785
# Epoch 36: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 78ms/step - accuracy: 0.5958 - loss: 1.0785 - val_accuracy: 0.6068 - val_loss: 1.0357 - learning_rate: 1.0000e-04
# Epoch 37/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5986 - loss: 1.0638
# Epoch 37: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 83ms/step - accuracy: 0.5986 - loss: 1.0638 - val_accuracy: 0.6096 - val_loss: 1.0180 - learning_rate: 1.0000e-04
# Epoch 38/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6068 - loss: 1.0511
# Epoch 38: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.6068 - loss: 1.0511 - val_accuracy: 0.6299 - val_loss: 0.9934 - learning_rate: 1.0000e-04
# Epoch 39/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6122 - loss: 1.0336
# Epoch 39: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.6121 - loss: 1.0337 - val_accuracy: 0.6306 - val_loss: 0.9788 - learning_rate: 1.0000e-04
# Epoch 40/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6126 - loss: 1.0326
# Epoch 40: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.6126 - loss: 1.0326 - val_accuracy: 0.6362 - val_loss: 0.9835 - learning_rate: 1.0000e-04
# Epoch 41/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6164 - loss: 1.0294
# Epoch 41: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.6164 - loss: 1.0294 - val_accuracy: 0.6257 - val_loss: 1.0031 - learning_rate: 1.0000e-04
# Epoch 42/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6100 - loss: 1.0296
# Epoch 42: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.6100 - loss: 1.0296 - val_accuracy: 0.6320 - val_loss: 0.9525 - learning_rate: 1.0000e-04
# Epoch 43/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6267 - loss: 1.0010
# Epoch 43: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 81ms/step - accuracy: 0.6267 - loss: 1.0010 - val_accuracy: 0.6362 - val_loss: 0.9648 - learning_rate: 1.0000e-04
# Epoch 44/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6184 - loss: 1.0116
# Epoch 44: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.6184 - loss: 1.0116 - val_accuracy: 0.6327 - val_loss: 1.0080 - learning_rate: 1.0000e-04
# Epoch 45/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6224 - loss: 0.9968
# Epoch 45: val_accuracy did not improve from 0.63827
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.6224 - loss: 0.9968 - val_accuracy: 0.6362 - val_loss: 0.9598 - learning_rate: 1.0000e-04
# Epoch 46/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6236 - loss: 0.9949
# Epoch 46: val_accuracy improved from 0.63827 to 0.64735, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.6236 - loss: 0.9949 - val_accuracy: 0.6473 - val_loss: 0.9647 - learning_rate: 1.0000e-04
# Epoch 47/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6252 - loss: 0.9882
# Epoch 47: val_accuracy did not improve from 0.64735
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.6252 - loss: 0.9882 - val_accuracy: 0.6432 - val_loss: 0.9675 - learning_rate: 1.0000e-04
# Epoch 48/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6370 - loss: 0.9634
# Epoch 48: val_accuracy improved from 0.64735 to 0.65014, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.6370 - loss: 0.9634 - val_accuracy: 0.6501 - val_loss: 0.9430 - learning_rate: 2.0000e-05
# Epoch 49/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6460 - loss: 0.9506
# Epoch 49: val_accuracy did not improve from 0.65014
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.6460 - loss: 0.9506 - val_accuracy: 0.6501 - val_loss: 0.9365 - learning_rate: 2.0000e-05
# Epoch 50/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6485 - loss: 0.9487
# Epoch 50: val_accuracy improved from 0.65014 to 0.66271, saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.6484 - loss: 0.9487 - val_accuracy: 0.6627 - val_loss: 0.9342 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 50.

# %%
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step

# %%
# Print classification report
print("\nClassification Report:")
print(classification_report(true_labels, validation_pred_labels,
                          target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14       191
#      disgust       0.00      0.00      0.00        22
#         fear       0.10      0.05      0.07       204
#        happy       0.26      0.27      0.27       354
#      neutral       0.15      0.22      0.18       246
#          sad       0.17      0.16      0.17       249
#     surprise       0.11      0.11      0.11       166
#
#     accuracy                           0.17      1432
#    macro avg       0.13      0.14      0.13      1432
# weighted avg       0.17      0.17      0.17      1432

# %%
def predict_emotion(image_path):
    from tensorflow.keras.preprocessing import image
    import numpy as np
    import matplotlib.pyplot as plt
    
    # Load and preprocess the image
    img = image.load_img(image_path, color_mode='grayscale', target_size=(48, 48))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    
    # Make prediction
    prediction = model.predict(img_array)
    emotion_labels = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
    predicted_emotion = emotion_labels[np.argmax(prediction)]
    
    # Display the image and prediction
    plt.figure(figsize=(8, 6))
    
    # Display original image
    plt.subplot(1, 2, 1)
    display_img = image.load_img(image_path, target_size=(48, 48))
    plt.imshow(display_img)
    plt.axis('off')
    plt.title('Input Image')
    
    # Display prediction probabilities
    plt.subplot(1, 2, 2)
    plt.bar(emotion_labels, prediction[0])
    plt.xticks(rotation=45)
    plt.title(f'Predicted Emotion: {predicted_emotion}\nConfidence: {np.max(prediction[0]):.2%}')
    
    plt.tight_layout()
    plt.show()
    
    return predicted_emotion, prediction[0]

# Use the function
emotion, probabilities = predict_emotion('/kaggle/input/2-data/image1.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step

# %%
def predict_emotion(image_path):
    from tensorflow.keras.preprocessing import image
    import numpy as np
    import matplotlib.pyplot as plt
    
    # Load and preprocess the image
    img = image.load_img(image_path, color_mode='grayscale', target_size=(48, 48))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    
    # Make prediction
    prediction = model.predict(img_array)
    emotion_labels = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
    predicted_emotion = emotion_labels[np.argmax(prediction)]
    
    # Display the image and prediction
    plt.figure(figsize=(8, 6))
    
    # Display original image
    plt.subplot(1, 2, 1)
    display_img = image.load_img(image_path, target_size=(48, 48))
    plt.imshow(display_img)
    plt.axis('off')
    plt.title('Input Image')
    
    # Display prediction probabilities
    plt.subplot(1, 2, 2)
    plt.bar(emotion_labels, prediction[0])
    plt.xticks(rotation=45)
    plt.title(f'Predicted Emotion: {predicted_emotion}\nConfidence: {np.max(prediction[0]):.2%}')
    
    plt.tight_layout()
    plt.show()
    
    return predicted_emotion, prediction[0]

# Use the function
emotion, probabilities = predict_emotion('/kaggle/input/2-data/image2.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
model.save('Best_model.keras')
